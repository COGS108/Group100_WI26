# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - What Impacts Steam Video Games Ratings?
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Our group was interested in the kinds of qualities of a game that impact the percentage of positive ratings video games receive on the platform Steam.
# We combined and analyzed two datasets on Kaggle that were updated within the last year containing information on ratings, game price, current active user base, user playtimes, and genres, from games published on Steam during the years 2013-2025 to see if these qualities had any associations with game ratings.
#
# Overall, we found that 1) the individual qualities of games don’t have particularly strong relationships with rating, 2) genres that are associated with player exploitation tend to be rated less positively, 3) games with higher peak playerbases receive greater numbers of positive reviews but also a lower ratio of positive to negative reviews, 4) overall games tend to be rated positively on average, though with high amounts of variability, 5) a K-nearest Neighbors algorithm performs with highest Precision and Recall on games with high percentages of positive ratings, 6) correlations may be deceptive regarding rating count versus rating percentages.
#
# Limitations we encountered include the rating system itself, with proportions of positive reviews not reflecting total rating count and vice versa, restraining the kinds of conclusions we can make, as well as the undersampling of games with low positive reviews, which requires further investigation into how such information can be most effectively analyzed.

# %% [markdown]
# ## Authors
#
# - Lauren: project visualization, conceptualization, project administration
# - Benson: software, experimental investigation, methodology
# - Joseph: software, experimental investigation, methodology
# - Heeyoung: writing - original draft, background research, data curation
# - Oscar: writing - review and editing, data curation

# %% [markdown]
# ## Research Question

# %% [markdown]
# **How do variables such as game genre, price, average length of playtime, and achievement number influence how Steam games are rated on the Steam shop globally since the platform's launch in 2003? Can these variables be used to predict how a Steam game might be rated?**
#
# Note: All the variables are attributes of games listed in the Steam storefront page for a game.
# Steam game genre refers to the available platforms and number of players it is targeting, price refers to the amount of currency in dollars required to purchase (including free games), average length of playtime refers to the average amount of time in hours it takes a player to reach an ending of the game for the first time, and achievement number refers to how many achievements can be attained by meeting in-game requirements for a game.
# We are restricting our population to games on Steam, and thus only reviewing ratings left on the Steam platform.
# We are interested in sampling across a time period of 26 years and investigating whether there are any significant patterns in the aforementioned variables.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Steam, a digital distribution service, lets its users buy video games from its digital store with a catalog of thousands of publishers, as well as install into and play video games from the users’ own digital library.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Important attributes of the games, such as their genre, price, number of game achievements are displayed on their store pages, allowing interested players to quickly get a feel for the game they may want to purchase.
#
# Reviews from players who purchased the game are also displayed, where each review provides a Positive or Negative rating, as well as how long the player played the game for.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)
#
# An overall game rating thus presents the percentage proportion of positive reviews in contrast to negative reviews, as well as the number of reviews submitted (eg. 80% positive reviews out of a 100 total reviews would seem more attractive than 80% positive reviews out of 10 total reviews).
#
# However, there could potentially be certain factors such as specific genres that tend to get rated more highly by players. Price could also impact player ratings by making people judge more expensive games more harshly. We were therefore interested in finding if there is any significant influence of the displayed variables on how a game is rated.
#
# When looking through previous group projects as resources, we found several that several projects previously also examined how the rating of something is influenced by multiple factors, such as how _Game of Thrones_ episode ratings, or restaurant Michelin Stars ratings.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)
#
#
# The Game of Thrones project classified episode features by order of rating impact through a Random Forest method and XGBoost Classifier Model, finding Character Presence and Episode Sentiment as the two most impactful features through both methods. The Michelin Stars project analyzed restaurant names and cuisines through Support Vector Regression and Linear Regression on price, attempting to predict star ratings through these factors, and found no particular directional relationship of these factors with Michelin Star Rating.
#
# Both projects provide valuable insight as to how our group could approach our question. We can find and specify variables most relevant to game rating and test specific algorithms to see if they could predict rating off these factors, since our project will use similar parameters due to Steam games also being a form of consumed entertainment. However, unlike previous projects that focused on how to give recommendations based on previous consumer activity, we aim to use concrete statistics such as cost and average play time to analyze the factors behind what gives a Steam game its ratings.
#
# There are also several publicly available repositories on github showing projects using steam games datasets for the purposes of building a recommendation system, such as one by Christian Craft that went into data analysis with the variables of reviews, popular tags, game details, and genres to use the K-Nearest Neighbors and Collaborative Filtering methods to determine games similar to an inputted game.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5)
#
# This project showed an example of how predictive machine learning could project similarities between given games, while our project would focus more on analyzing the existing potential impacts on game rating.
#
# Overall, these previous projects inspired us on the topic and methods related to analyzing data on ratings, and gave us a sense of what direction our project should head towards. We aim to take our investigation one step further and address the unexplored potential in whether the way players evaluate Steam games is impacted by objective properties of the games such as price and play time rather than subjective properties such as writing and style.
#
# In general, game ratings are a reflection of the quality and enjoyment a game delivers to its consumers. Our topic of finding variable relationships to game ratings is significant as it could potentially give game creators a reference on what they should focus on during development to get the best reception possible from players. For consumers, this will increase their engagement and improve their perception of the game, which could therefore increase consumer rates of these games. For developers, increased consumption can result in increased sales of these games, allowing them to generate more revenue for their company and access a more universal player base.
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Steam About Page. https://store.steampowered.com/about
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Information about Steam Reviews. https://help.steampowered.com/en/faqs/view/2DA6-9CB3-F84A-643E.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) COGS 108 Game of Thrones Project. https://github.com/COGS108/FinalProjects-Sp20/blob/master/FinalProject_group39.ipynb.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) COGS 108 Michelin Stars Project. https://github.com/COGS108/FinalProjects-Sp20/blob/master/FinalProject_group65.ipynb.
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Steam Games Recommendation Project. https://github.com/craftstl97/SteamGamesAnalysis/blob/main/markdown/SemesterProject.ipynb.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that there is a strong relationship between variables such as price, genre, and player count with the overall rating of a game, that may be used to predict game rating.
#
# **Price:** We predict a strong negative correlation between game ratings and price. If a game had a higher cost, that may cause players to have higher expectations of a game's quality, with the high cost of certain games coming from game complexities and design, studio reputation, and development time.
#
# **Genre:** Additionally, we predict that game genre has a high influence on the rating of a game, with more popular genres such as FPS games generally receiving higher ratings than puzzle or gacha games due to some players feeling frustrated over genre-specific mechanics such as overly difficult/unintuitive puzzles or unforgiving gacha rates.
#
# **Player Count:** We also predict a strong positive correlation between active player count and positive ratings. With higher numbers of players, more players would leave positive reviews and dominate negative reviews by proportion.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#     - Dataset Name: Steam games Dataset 2025
#     - Link to the dataset: https://www.kaggle.com/datasets/srgiomanhes/steam-games-dataset-2025/data
#     - Number of Observations: 71429 games
#     - Number of variables: 21 columns
#     - Most relevant variables:
#         - steam_appid: ID of the game within Steam's database
#         - name: Name of a given game
#         - categories: Tags used to help describe what the games feature
#         - genres: Tags used to help describe the gameplay content
#         - release-date: Could create connections and correlations with reviews
#         - is_free: Makes it easier to filter out free games from not
#     - Shortcomings:
#         - Lacks current cost, only has initial pricing in USD
#         - Smaller side of datasets
# - Dataset #2
#     - Dataset Name: Steam Games Dataset
#     - Link to the dataset: https://www.kaggle.com/datasets/fronkongames/steam-games-dataset/data
#     - Number of observations: 122611 games
#     - Number of variables: 40 columns
#     - Relevant variables:
#         - AppID: ID of the game within Steam's database
#         - Name: Name of a given name
#         - Estimated Owners: Shows how successful the game was at selling
#         - Playtime: Measure of how successful the game is at retaining players
#         - Peak CCU: Peak concurrent players - Measure of how successful a game was at its peak
#         - Positive/Negative: Reviews, measures player's actual enjoyment of the game
#         - Metacritic/User Score: More official, third party scores of the game, from a critic and user standpoint
#         - Price: The cost of the game
#     - Shortcomings:
#         - Was not initially tidy, missing a comma
#         - Very large dataset takes a lot of memory to process
#
# Each dataset deserves either a set of bullet points as above or a few sentences if you prefer that method.
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.

# %% [markdown]
# ### Setup and Packages

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified


# UNCOMMENT BELOW IF MAKING MODULES.

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm


# UNCOMMENT BELOW CODE IF CODE NEVER RUN BEFORE 

# !pip install -q gdown
# import gdown

# file_id = "166o0UjmSgPYyMD8vzIe178IhtWHKG2Q0"  # the long string after /d/ in the share link
# url = f"https://drive.google.com/uc?id={file_id}"

# gdown.download(url, "data/00-raw/steam_games_2.csv", quiet=False)

# import sys
# sys.path.append('./modules') # this tells python where to look for modules to import

# import get_data # this is where we get the function we need to download data


# UNCOMMENT BELOW CODE IF NEVER RUN BEFORE 

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 


# datafiles = [
#    { 'url': 'https://drive.google.com/uc?id=1lF1c8fHKD7Ymzzlw3dNL_Q9IbdsgKagh&export=download', 'filename':'steam_games_1.csv'},
#    { 'url': 'https://drive.google.com/uc?id=17VtzFY3WFINJ3buja9MoNRjZzBBVdKgA&export=download', 'filename':'steam_games_3.csv'}
# ]

# get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import ast

# %% [markdown]
# ### Steam Games Dataset: Genres, Achievements, Reviews
# #### Data Cleaning
#
# **NOTE** The final report should not be overly long.  If this wrangling step is huge and complicated you should remove these sections from the final report and replace them with a statement like "To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis"

# %% [markdown]
# Overall, we want to extract any variables related to Genre, Achievements, Playtime, and most importantly Reviews as relevant columns from Dataset #1 and #2, and then merge the datasets for easier use.

# %% [markdown]
# First, with Dataset #1, we examine this dataset for its formatting and missing and or unusual values.
# In this case, after searching for any empty strings or key words related to empty data, we did not find any missing data.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
# Step A: Load the Dataset
steam1 = pd.read_csv("data/00-raw/steam_games_1.csv")

#Step B: Dataset Tidiness
steam1.info

#Step C: Dataset Size
steam1.shape

#Step D: Missing Data
steam1.isna().sum #0 for every column
(steam1 == "").sum() #Checks for empty strings, 0 for every column
steam1.apply(lambda col: col.astype(str).str.lower().isin(["unknown", "n/a", "na", "null"]).sum()) #Checks for any of the terms in any given column. 1 in "name", 0 elsewhere
steam1.apply(lambda col: col.astype(str).str.strip().eq("").sum()) #Checks for white spaces, 0 in all columns

#One game is named one of the trigger words, so check it out
steam1[steam1["name"].str.lower().isin(["unknown", "na", "n/a", "null", "NaN"])]
#After further investigation via official Steam page steam_appid lookup, "Unknown" is the name of a game, therefore a false positive.

#Meaning, there is no missing data.
# Out:
#       steam_appid     name    developers    publishers  \
# 9285       996730  Unknown  ['Yorm.Ent']  ['Yorm.Ent']
#
#                                categories                  genres  \
# 9285  ['Single-player', 'Family Sharing']  ['Adventure', 'Indie']
#
#       required_age  n_achievements    platforms  is_released  ...  \
# 9285             0              22  ['windows']         True  ...
#
#      additional_content total_reviews  total_positive  total_negative  \
# 9285                 []             3               1               2
#
#       review_score  review_score_desc positive_percentual  metacritic  \
# 9285           0.0     3 user reviews                33.3           0
#
#       is_free  price_initial (USD)
# 9285    False                 3.99
#
# [1 rows x 21 columns]

# %% [markdown]
# We then examined the dataset for outliers and or suspicious entries that could detract from our research question.

# %%
#Step E: Outliers and/or suspicious entries
steam1.describe()
# Out:
#         steam_appid  required_age  n_achievements  total_reviews  \
# count  7.142900e+04  71429.000000    71429.000000   7.142900e+04
# mean   1.613700e+06      2.573227       16.079478   4.102497e+02
# std    8.625559e+05     13.591997      138.084319   8.389934e+03
# min    7.300000e+02      0.000000        0.000000   0.000000e+00
# 25%    9.296400e+05      0.000000        0.000000   0.000000e+00
# 50%    1.533470e+06      0.000000        0.000000   2.000000e+00
# 75%    2.383530e+06      0.000000       16.000000   1.900000e+01
# max    3.430140e+06     97.000000     9821.000000   1.279700e+06
#
#        total_positive  total_negative  review_score  positive_percentual  \
# count    7.142900e+04    71429.000000  71429.000000         71429.000000
# mean     3.602238e+02       50.025886      2.192849            46.113290
# std      7.409672e+03     1171.055349      3.175885            41.961702
# min      0.000000e+00        0.000000      0.000000             0.000000
# ...

# %% [markdown]
# Price seemed to have a completely separate use for developers where developers would intentionally put unfeasibly high prices to detract from early purchases just to save their game page on Steam, which would run counter to our research question involving players actually playing and reviewing the game. This column was removed.

# %%
#Note: price_initial has a max of $999.98
steam1[steam1["price_initial (USD)"] > 100]
#There are a lot of games with an initial price range of over $100 USD, so check how many
len(steam1[steam1["price_initial (USD)"] > 100])
#There are 171 rows, meaning 171 games with an initial price range of over $100 USD. 
#This means this likely is just a strategy that developers intentionally use to prevent early purchases, while saving their game page on Steam.
#Because of this inaccuracy to our research question, we cannot use this column from this dataset.
# Out:
# 171

# %% [markdown]
# The standard gaming age rating goes to 21. Any game with 30+ age rating indicates outlier and/or possibly illegitimate values, which will be removed.

# %%
#Note: required_age has a max of 97. 
(steam1["required_age"] > 30).sum()
#There are 2519 games with a required age of over 30, which is unusual considering the standard age rating systems go up to 21+. 
#Having a required age count past 21 is unusual, and could indicate illegitimate age ratings.
#Meaning, games with 30+ age ratings will be removed for improved data accuracy.
# Out:
# 2519

# %% [markdown]
# Some games have achievements in the thousands, but for the sake of our question would still count as games. However, we will take note of if they produce unusual patterns in the data.

# %%
#Addressing number of achievements, while 9.8k achievement count seem unusual, this should be noted, but not immediately cleaned
steam1[steam1["n_achievements"] > 300][["name", "n_achievements"]].head()
#All team members reached the consensus to leave these games in, as they are still considered games
# Out:
#                                     name  n_achievements
# 9834   Halo: The Master Chief Collection             700
# 12696                    Girl and Goblin            1552
# 12733                        Hentai Girl            3000
# 12861                         XXX Puzzle             308
# 12874               Dinosaur Hunt Puzzle            4987

# %% [markdown]
# The data was saved to only contain the relevant columns.

# %%
#Step F: Cleaning the Data

steam1 = steam1[steam1["required_age"] <= 30]
steam1 = steam1[steam1["is_released"] == True]
steam1 = steam1.drop(columns=["price_initial (USD)", "developers", "publishers", "platforms", "review_score_desc", "additional_content", "required_age", "is_released"])

#Removed the data considered harmful to our data, or unnecessary.

#Step G: Saving Processed Dataset
steam1.to_csv("data/02-processed/steam_games_1_cleaned.csv", index = False)

steam1.head()
# Out:
#    steam_appid                  name  \
# 0      2719580              勇者の伝説の勇者
# 2      2719600  Lorhaven: Cursed War
# 3      2719610          PUIQ: Demons
# 4      2719650        Project XSTING
# 7      2719710         Manor Madness
#
#                                           categories  \
# 0                ['Single-player', 'Family Sharing']
# 2  ['Single-player', 'Multi-player', 'PvP', 'Shar...
# 3  ['Single-player', 'Steam Achievements', 'Famil...
# 4  ['Single-player', 'Steam Achievements', 'Steam...
# 7  ['Single-player', 'Steam Achievements', 'HDR a...
#
#                                               genres  n_achievements  \
# 0                                ['Casual', 'Indie']               0
# 2                                ['RPG', 'Strategy']              32
# 3               ['Action', 'Casual', 'Indie', 'RPG']              28
# 4      ['Action', 'Casual', 'Indie', 'Early Access']              42
# ...

# %% [markdown]
# ### Steam Games Dataset: Cost, Genres

# %% [markdown]
# We do the same with Dataset #2.

# %% [markdown]
# This dataset initially had a formatting issue, missing a column in the header and mismatching the column names to their columns. However, editing in a comma to the CSV displayed the data correctly.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
#Step A: Load the Dataset
steam2 = pd.read_csv("data/00-raw/steam_games_2.csv")
#Step B: Dataset tidiness
steam2.info
steam2.columns
#Tidiness was an issue. 
#Initially, the original CSV file missed a column in the header, meaning all information was incorrectly displayed
#After editing the comma back in using a text editor, all information is displayed correctly, and therefore tidy.

#Step C: Dataset Size
steam2.shape
#Size of (122611, 40)
# Out:
# (122611, 40)

# %% [markdown]
# We then took a general look at this dataset’s missing values.

# %% [markdown]
# Genres and Categories from this dataset tended to be missing, which we took note of.

# %%
#Step D: Missing Data
steam2.isna().sum() # A lot of missing data. A lot of it is unnecessary, but some notable missing information are: 8413; Genres, 8953; Categories, 1; Name
steam2[["Genres", "Categories"]].isna().sum() #Missing 8413 Genres, and 8953 Categories
steam2[["Genres", "Categories"]].isna().mean()*100 #6.86% of genres are missing, while 7.3% of categories are missing
# Out:
# Genres        6.861538
# Categories    7.301955
# dtype: float64

# %% [markdown]
# However, there were no missing data in the form of empty strings, and missing data in other forms not captured above were of irrelevant variables we would not consider in analysis.

# %%
steam2.apply(lambda col: col.astype(str).str.strip().eq("").sum()) #None have empty strings
steam2.apply(lambda col: col.astype(str).str.lower().isin(["Unknown", "n/a", "na", "NaN", "null"]).sum()) #Some irrelevant information, such as About the game and Support URL, are missing.
# Out:
# AppID                         0
# Name                          0
# Release date                  0
# Estimated owners              0
# Peak CCU                      0
# Required age                  0
# Price                         0
# Discount                      0
# DLC count                     0
# About the game                1
# Supported languages           0
# Full audio languages          0
# Reviews                       0
# Header image                  0
# Website                       0
# Support url                   3
# Support email                 0
# Windows                       0
# Mac                           0
# Linux                         0
# Metacritic score              0
# Metacritic url                0
# User score                    0
# Positive                      0
# Negative                      0
# Score rank                    0
# Achievements                  0
# Recommendations               0
# Notes                         0
# ...

# %% [markdown]
# Games with missing genres and categories also commonly tended to be free, suggesting a potential association.

# %%
steam2[steam2["Genres"].isna()]["Price"].describe() #Average price of games with missing genres is 0.096, with the max being 129.99, and std being 1.88. 75% is 0, showing that most of them are free.
#This seems more systemic, as most of the games that are missing Genres are free, meaning that these games likely do not have genres for many reasons
# Out:
# count    8413.000000
# mean        0.096043
# std         1.884866
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       129.990000
# Name: Price, dtype: float64

# %%
steam2[steam2["Categories"].isna()]["Price"].describe() #Similar with Categories, which may indicate that these free games are not popular enough to be considered.
# Out:
# count    8953.000000
# mean        1.360884
# std         8.660655
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       299.990000
# Name: Price, dtype: float64

# %% [markdown]
# The Price column in this dataset was also examined, and considering the industry standard of 70 dollar games as being expensive already, we considered games above 100 dollars as outliers.

# %%
#Step E: Outliers and/or suspicious entries
steam2.describe() #Price of 999.98 max, which is an outlier. 
(steam2["Price"] > 100).sum() #309
#In the current market of video games, game prices should not reach over 100. 
#AAA games standards, known for being the priciest of games, are $70, so anything over $100 should be considered unreasonable, and likely meant to save game page space for an unfinished game.
# Out:
# 309

# %% [markdown]
# We removed games with prices over 100 dollars, dropped irrelevant columns, and dropped games that had no Genres or Categories listed, as we are centrally interested in examining those in our analysis.

# %%
#Step F: Cleaning Data
steam2 = steam2[steam2["Price"] <= 100]
steam2 = steam2.drop(columns=["Discount", "Required age", "DLC count", "About the game", "Supported languages", "Full audio languages", "Reviews", "Header image", "Website", "Support url", "Support email", "Windows", "Mac", "Linux", "Metacritic url", "Recommendations", "Notes", "Developers", "Publishers", "Screenshots", "Movies", "Score rank", "Tags"])
steam2 = steam2.dropna(subset=["Genres", "Categories"]) #Drop the ones where there are no genres, as it is a necessary component

steam2.isna().sum()
steam2.shape #We are left with 113232 entries

#Step G: Uploading data
steam2.to_csv("data/02-processed/steam_games_2_cleaned.csv", index = False)

steam2.head()
# Out:
#      AppID                                   Name  Release date  \
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
# 5  1654170                               Agony VR   Apr 5, 2023
#
#   Estimated owners  Peak CCU  Price  Metacritic score  User score  Positive  \
# 1        0 - 20000         0   5.24                 0           0       252
# 2        0 - 20000         0   4.99                 0           0        21
# 3        0 - 20000         1   8.99                 0           0         0
# 4        0 - 20000         0   4.99                 0           0         0
# 5        0 - 20000         0  13.99                 0           0         0
#
#    Negative  Achievements  Average playtime forever  \
# 1         3             0                         8
# ...

# %% [markdown]
# Finally, we merged the two datasets based on the listed “steam_appid” column of dataset #1 and the AppID column of dataset #2. This is an ID number unique and specific to each game that Steam uses to reference the game within its servers.

# %%
#Merging the two datasets based on ID of the game.
steam1 = steam1.rename(columns={"steam_appid": "AppID"})
steam_games = pd.merge(steam1, steam2, on="AppID", how="inner")
steam_games.shape #54250 valid data
# Out:
# (54250, 29)

# %% [markdown]
# We remove duplicate columns from the dataset and reorder the columns in a readable format.

# %%
steam_games.head() #We have duplicate positive and negative columns, with different data. Best choice is to only pick one.
steam_games = steam_games.drop(columns=["total_reviews", "total_positive", "total_negative", "Name", "metacritic", "Achievements", "Categories", "Genres", "Release date", "review_score", "positive_percentual"])

#Although we only have 1 of each variable now, we will want to reorder it in a sensible manner

steam_games = steam_games[["AppID", "name", "release_date", "Price", "genres", "categories", "Estimated owners", "Peak CCU", "Average playtime forever", "Average playtime two weeks", "Median playtime forever", "Median playtime two weeks", "Positive", "Negative", "Metacritic score", "User score", "is_free"]]
# dropping final irrelevant columns
steam_games = steam_games.drop(columns=['Metacritic score', 'User score'])
# convert string literals to Python list datatype
steam_games['genres'] = steam_games['genres'].apply(lambda x: ast.literal_eval(x))
steam_games['categories'] = steam_games['categories'].apply(lambda x: ast.literal_eval(x))

# %%
#Now that everything is to our liking, upload
steam_games.to_csv("data/02-processed/steam_games.csv", index = False)
steam_games.head()
steam_games.describe()
# Out:
#               AppID         Price      Peak CCU  Average playtime forever  \
# count  5.425000e+04  54250.000000  5.425000e+04              5.425000e+04
# mean   1.513360e+06      4.250611  5.239629e+01              2.925508e+02
# std    8.243597e+05      5.593286  4.646676e+03              1.677237e+04
# min    7.300000e+02      0.000000  0.000000e+00              0.000000e+00
# 25%    8.807850e+05      0.790000  0.000000e+00              0.000000e+00
# 50%    1.424895e+06      2.490000  0.000000e+00              0.000000e+00
# 75%    2.284425e+06      5.190000  0.000000e+00              6.000000e+00
# max    3.430140e+06     99.990000  1.013936e+06              3.429544e+06
#
#        Average playtime two weeks  Median playtime forever  \
# count                54250.000000             5.425000e+04
# mean                    14.379447             2.569403e+02
# std                    324.292284             1.674337e+04
# min                      0.000000             0.000000e+00
# ...

# %% [markdown]
# Now, our data is ready and usable for analysis.

# %% [markdown]
# ## Results
# ### Exploratory Data Analysis
# #### Overall Relationships

# %% [markdown]
# First, we get a general sense of the relationships existing within the variables we are examining for impact. We accomplished this by using a heat map to see if any numerical variables could possibly show correlations to examine.

# %%
steam_filter = steam_games.select_dtypes(include = ['float64', 'int64']).astype(float) # filter out only the numerical columns bc we have separate graphs for the categorical ones 
steam_filter = steam_filter.drop(columns = ['AppID']) # we're not analyzing each type of game in the heatmap, so we don't need the AppID column

# set figure size
plt.figure(figsize=(12, 10))  

# compute the correlation matrix 
steam_filter_corr = steam_filter.corr(numeric_only=True) 

# create heatmap with a single color gradient to show the lowest to highest correlation values and set tile for heatmap 
steam_heatmap = sns.heatmap(data=steam_filter_corr, annot=True, cmap='Reds') 
plt.title("Correlation Matrix for Steam Games")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix for Steam Games')

# %% [markdown]
# Notably, unlike our hypothesis, ratings had weak relationships with most variables taken alone.
# Playtimes tended to have a moderate to strong relationship with each other, which made sense. With a high playtime for a shorter period of time like two weeks, the more likely they would be having a high playtime overall.
# Interestingly, Peak CCU was correlated strongly with the number of Positive and Negative reviews, indicating games that tended to have more active players also tended to leave more reviews.

# %% [markdown]
# Overall, however, most of the numerical independent variables we selected for their potential impact on ratings do not seem to be correlated with each other.

# %%
#create an upper triangle mask, using k=1 to exclude the diagonal and duplicate values and only have unique correlations
mask = np.triu(np.ones(steam_filter_corr.shape), k=1).astype(bool) 

steam_filter_corr_unique = steam_filter_corr.where(~mask).stack().reset_index() #using ~mask will only keep the lower triangle in the amtrix 
steam_filter_corr_unique.columns = ['Feature1', 'Feature2', 'Correlation'] #categorize the columns of unique pair correlations into a column of the first feature, second feature, and their correlation amount

# plot distribution of correlations with a histogram
distribution = sns.histplot(steam_filter_corr_unique, bins=20)

# set x, y, and title labels 
plt.xlabel("Absolute Correlation") 
plt.ylabel("Count") 
plt.title("Distribution of Variable Correlation in Correlation Matrix") 

# count is relatively the highest near 0, illustrating that most of the variables in the matrix have little to no correlation with each other
# Out:
# Text(0.5, 1.0, 'Distribution of Variable Correlation in Correlation Matrix')

# %% [markdown]
# #### Price and Ratings

# %% [markdown]
# Going back to our hypothesis, we still wanted to see how price impacts game ratings.
# One option would be to do this through a boxplot and grouping games by general price range against the proportion of positive reviews they tended to receive.

# %%
# ranges are 0-19.99, 20-39.99, 40-59.99, 60-79.99, 80-99.99 
# using price column, create a new column that includes these ranges
bins = [0, 19.99, 39.99, 59.99, 79.99, 99.99] 
labels = ['$0-$19.99', '$20-$39.99', '$40-$59.99', '$60-$79.99', '$80-99.99'] # create categories for price ranges 
steam_games['Price Range'] = pd.cut(steam_games['Price'], bins=bins, labels=labels, include_lowest=True) 

# calculate percentage of pos reviews (pos/(pos+neg)) and add that as a new column called Percentage of Positive
total = steam_games['Positive'].astype(float) + steam_games['Negative'].astype(float) 
steam_games['Percentage of Positive'] = (steam_games['Positive'] / total * 100).fillna(0) 

#set figure size 
plt.figure(figsize=(8, 5)) 

# barplot of the positive review percentage average vs each price range of the games 
sns.boxplot(data=steam_games, x='Price Range', y='Percentage of Positive', hue='Price Range', palette='tab10') 
plt.title("Percentage of Positive Reviews and Price Range")

# all the price ranges below $80 seem to have a higher percentage of positive reviews, indicating a negative correlation between higher cost and positive reviews
# Out:
# Text(0.5, 1.0, 'Percentage of Positive Reviews and Price Range')

# %% [markdown]
# We hypothesized that price would have a negative relationship with reviews, and generally all games priced below 80 dollars tended to show higher mean % of positive reviews with overlapping ranges, possibly even reaching 100% positive ratings.
#
# Meanwhile, games priced above showed the lowest mean % positive reviews, as well as the lowest potential maximum % of positive ratings. This aligns with the fact that 70-80 dollars seems to be the industry standard of the highest price in gaming, and players may tend to rate expensive games with more judgment.
#
# However, all price ranges generally displayed a high % of positive reviews, with all price groupings tending to overlap and means tending to be above 50% positive reviews. This does not support our hypothesis with a strong association between price and rating, as game ratings do not seem to significantly differ by price.

# %% [markdown]
# #### Which genre is best?
#
# We wanted to explore the effect that genre had on how well a game performed in the Steam shop. To achieve this, we used the ratio of positive reviews to total reviews as our test statistic and used one-hot encoding to compensate for the fact that each game has multiple genres attached. One challenge we encountered while creating this EDA was that the 'rating_percent' column is originally a string containing the code for a Python list that held the genres. To solve this, we had to import the 'ast' package. Additionally, some genres had artificially inflated scores due to having very few entries, so we dropped them.

# %%
# create a copy of the steam_games dataframe for manipulation
copy = steam_games.copy()

# add a column 'rating_percent' that describes the ratio of positive reviews to total reviews  
copy['rating_percent'] = copy['Positive'] / (copy['Positive'] + copy['Negative'])

# get all the unique genres from the genres column
genres = pd.Series([i for lst in copy['genres'] for i in lst]).unique()

# create a new one-hot column for every unique genre in 'genres'
for genre in genres:
    copy[genre] = copy['genres'].apply(lambda x: genre in x)
genres_one_hot = copy[genres].join(copy['rating_percent']).dropna(subset = 'rating_percent')

# drop genres that have less than 50 games assigned to them and calculate the means
counts = copy[genres].sum()
valid_genres = counts[counts > 50].index
genre_means = (genres_one_hot[valid_genres].multiply(copy['rating_percent'], axis=0).sum() / counts[valid_genres]).sort_values()

# create the visualization and make it pretty
ratings_by_genre_vis = sns.barplot(x = genre_means.index, y = genre_means.values, palette='viridis')
ratings_by_genre_vis.set_xticklabels(ratings_by_genre_vis.get_xticklabels(), rotation=45, ha='right')
ratings_by_genre_vis.set_title('Positive Rating Ratio Given Game Genre') 
ratings_by_genre_vis.set(xlabel = 'Genre', ylabel = 'Average Positive Reviews Given Genre')
plt.show()
# Out:
# /tmp/ipykernel_3238/1184551971.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ratings_by_genre_vis = sns.barplot(x = genre_means.index, y = genre_means.values, palette='viridis')
# /tmp/ipykernel_3238/1184551971.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ratings_by_genre_vis.set_xticklabels(ratings_by_genre_vis.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# #### Results
#
# Looking at the visualization, we can see that the lower-rated genres include 'Massively Multiplayer' and 'Gore'. MMOs tend to receive lower ratings due to long grinds and unfair monetary policies for their F2P players. Gorey games also tend to receive lower ratings due to being generally unappealing to wider audiences. On the other hand, 'Indie' games are generally more well-received since they are often more passionate projects compared to AAA games, while 'Action' games are more engaging, creating a sharp contrast with the lower ratings given to the 'Massively Multiplayer' genre. As a whole, genres tend to have a significant effect on the rating of a game.

# %% [markdown]
# ### Playtime Relation
#
# We want to compare the average playtime of the last two weeks when the dataset was created to the overall average playtime forever.

# %%
#Create a dataframe with just the two columns we will be comparing
playtime_df = steam_games[["Average playtime two weeks", "Average playtime forever"]].copy()

#Remove any potential missing values in the dataset
playtime_df = playtime_df.dropna()

#Remove rows in which either column is 0. Indicates that no one has played the game, which is irrelevant to our analysis
playtime_df = playtime_df[
    (playtime_df["Average playtime two weeks"] > 0) |
    (playtime_df["Average playtime forever"] > 0)
]

#Create a regplot, where each instance is a game.
plt.figure(figsize=(8,6))
sns.regplot(
    data = playtime_df,
    x = "Average playtime two weeks",
    y = "Average playtime forever",
    scatter_kws = {"alpha": 0.3},
    line_kws = {"color": "red"}
)

#Label the axes
plt.title("Average Playtime Two Weeks vs Average Playtime Forever")
plt.xlabel("Average playtime two weeks (minutes)")
plt.ylabel("Average playtime forever (minutes)")
plt.show()

# %% [markdown]
# There are some clear outliars. Although this is theoretically possible, 2 weeks only consists of 20160 minutes. Also, note the extreme values on playtime forever. It is unlikely someone played a game for 3500000 minutes, let alone over 1.7 million, equivalent to 3.2 years. Therefore, we will need to clear this up.

# %%
playtime_df = playtime_df[
    (playtime_df["Average playtime forever"] < 20000) &
    (playtime_df["Average playtime two weeks"] < 5000)
]
#Create a regplot, where each instance is a game.
plt.figure(figsize=(8,6))
sns.regplot(
    data = playtime_df,
    x = "Average playtime two weeks",
    y = "Average playtime forever",
    scatter_kws = {"alpha": 0.3},
    line_kws = {"color": "red"}
)

#Label the axes
plt.title("Average Playtime Two Weeks vs Average Playtime Forever")
plt.xlabel("Average playtime two weeks (minutes)")
plt.ylabel("Average playtime forever (minutes)")
plt.show()

# %% [markdown]
# What this tells us is that many of the games are already inactive or dead, as in minimal players. While their average playtime forever may reach high numbers, their average playtime in two minutes remains at a small number, which shows that they have failed to keep a consistently high number of players. This information can help us understand player enegagment behavior, which can influence game ratings.
#
# A lot of the reviews in our total group are likely from inactive games or games with 0 average play time in the last two weeks. This can reflect in the game's ratings; a game may have failed to create more updates to sustain the player base or created updates that are insufficient to satisfy the playerbase's wants.

# %% [markdown]
# ### Peak CCU (Concurrent players) vs Positive/Negative reviews

# %% [markdown]
# Next, we want to examine how peak CCU may affect the amount of positive and negative reviews a game may get. To do this, we will separate the Peak CCU into multiple bins, and from there compare the reviews to each bin to further understand how a game's peak popularity, or when people play the game the most, correlate with game reviews. This will allow us to get a more accurate reading from a bigger group of people, since at Peak CCU, it is more likely that the group of people who have played this game include those outside of the intended audience, giving a larger sample of players.

# %%
#Take needed columns into a separate dataframe
ccu_df = steam_games[["Peak CCU", "Positive", "Negative"]].copy()

#Remove any potential missing values
ccu_df = ccu_df.dropna()

# Keep only valid values within each column
ccu_df = ccu_df[
    (ccu_df["Peak CCU"] > 0) &
    (ccu_df["Positive"] >= 0) &
    (ccu_df["Negative"] >= 0)
]

# Create bins for Peak CCU
bins = [0, 10, 100, 1000, 10000, 100000, ccu_df["Peak CCU"].max()]
labels = ["0-10", "11-100", "101-1,000", "1,000-10,000", "10,000-100,000", "100,000+"]

ccu_df["CCU Range"] = pd.cut(
    ccu_df["Peak CCU"],
    bins=bins,
    labels=labels,
    include_lowest=True
)

#Then, group by bins, and get the avg positive/negative reveiws
ccu_grouped = ccu_df.groupby("CCU Range")[["Positive", "Negative"]].mean()

#Format it correctly for seaborn
ccu_format = ccu_grouped.reset_index().melt(
    id_vars = "CCU Range",
    value_vars = ["Positive", "Negative"],
    var_name = "Review Type",
    value_name = "Average Reviews"
)

#Create plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=ccu_format,
    x = "CCU Range",
    y = "Average Reviews",
    hue = "Review Type"
)

#Label plot
plt.title("Average Positive and Negative Reviews by Peak CCU Range")
plt.xlabel("Peak CCU Range")
plt.ylabel("Average Number of Reviews")
plt.xticks(rotation=30)
plt.show()
# Out:
# /tmp/ipykernel_3238/600174193.py:26: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ccu_grouped = ccu_df.groupby("CCU Range")[["Positive", "Negative"]].mean()

# %% [markdown]
# This bar chart shows the average number of positive and negative reviews across different Peak CCU ranges. Note that as the Peak CCU increases, so does the number of positive and negative review count, showing that more popular games review significantly more reviews. This is expected, as there would be more opportunities to leave reviews. However, across all ranges, positive reviews seem to consistently surpass negative reviews, showing that the either people are more likely to leave positive reviews rather than negative, or overall tend to be more favorable towards the game. However, one important thing to note is how the lower Peak CCU ranges have a higher positive to negative ratio, whereas the popular games with over 100k in Peak CCU tend to have more negative reviews than other ranges in terms of percentages.

# %% [markdown]
# ### Positive vs Negative Reviews
#
# We initially wanted to investigate the general pattern of positive and negative reviews by creating a stacked barplot that illustrates the distribution of each type of review across the games in the dataset. However, we ran into a complication: the dataset we analyzed was very large and it would be hard to show the distribution of positive and negative reviews for every single game. We therefore decided to select the five most popular genres of games and analyze the general pattern of positive and negative reviews for a game per each genre.

# %%
# initialize an empty list to add all the genres 
list_1 = []
# combine each list in 'genres' to find which genres are most popular
steam_games.genres.apply(lambda x: list_1.extend(x))

#check value counts of our updated list_1
pd.Series(list_1).value_counts()
# Out:
# Indie                    38990
# Casual                   23547
# Action                   22570
# Adventure                21583
# Simulation               11126
# Strategy                 10429
# RPG                       9946
# Early Access              5994
# Free To Play              4969
# Sports                    2295
# Racing                    1883
# Massively Multiplayer     1340
# Utilities                  298
# Violent                    259
# Design & Illustration      183
# Education                  161
# Gore                       155
# Animation & Modeling       151
# Video Production            96
# Game Development            86
# Audio Production            67
# Software Training           57
# Nudity                      55
# Sexual Content              51
# Photo Editing               43
# Web Publishing              32
# Accounting                   7
# Movie                        2
# Documentary                  1
# Episodic                     1
# ...

# %% [markdown]
# From this list of all the genres in our dataset, we see that Indie, Casual, Action, Adventure, and Simulation are the five most common genres. Therefore, we will intialize separate lists for games of these genres and append them with their respective genres. For example, we will add all the games that only have "Indie" in their list of genres to the indie list and all the games that only have "Casual" in their list of genres to the casual list.

# %%
# Initialize empty lists to put the top 5 genres in
indie_list = []
casual_list = [] 
action_list = []
adventure_list = []
simulation_list = []

# append the games that only have indie to the indie list and the games that only have casual to the casual list, etc
for i in steam_games.genres:
    indie_list.append(('Indie' in i) & ('Casual' not in i) & ('Action' not in i) & ('Adventure' not in i) & ('Simulation' not in i))
    casual_list.append(('Indie' not in i) & ('Casual' in i) & ('Action' not in i) & ('Adventure' not in i) & ('Simulation' not in i)) 
    action_list.append(('Indie' not in i) & ('Casual' not in i) & ('Action' in i) & ('Adventure' not in i) & ('Simulation' not in i))
    adventure_list.append(('Indie' not in i) & ('Casual' not in i)& ('Action' not in i) & ('Adventure' in i) & ('Simulation' not in i))
    simulation_list.append(('Indie' not in i) & ('Casual' not in i) & ('Action' not in i) & ('Adventure' not in i) & ('Simulation' in i))

# create separate dataframes for each genre, add a column called "genre" that contains the genre to every row 
casual_df = steam_games[casual_list].loc[:,['name', 'Positive', 'Negative']].reset_index(drop = True)
casual_df['genre'] = 'Casual'

indie_df = steam_games[indie_list].loc[:,['name', 'Positive', 'Negative']].reset_index(drop = True)
indie_df['genre'] = 'Indie'

action_df = steam_games[action_list].loc[:,['name', 'Positive', 'Negative']].reset_index(drop = True)
action_df['genre'] = 'Action'

adventure_df= steam_games[adventure_list].loc[:,['name', 'Positive', 'Negative']].reset_index(drop = True)
adventure_df['genre'] = 'Adventure'

simulation_df = steam_games[simulation_list].loc[:,['name', 'Positive', 'Negative']].reset_index(drop = True)
simulation_df['genre'] = 'Simulation'

# concat the 5 dataframes together, then melt it to ensure that Positive and Negative will combine together into a single column called "review"
# this will be helpful for plotting the dataframe 
top5_df = pd.concat([casual_df, indie_df, action_df, adventure_df, simulation_df])
melt_top5_df = pd.melt(top5_df, id_vars=['name','genre'], value_vars=['Positive','Negative'], var_name='review')

# create a barplot of the melted dataframe, use review to group positive and negative reviews together
sns.barplot(x = 'genre', y = 'value',hue = 'review',data = melt_top5_df, palette='dark')

#setting plot labels
plt.title('Observing Positive/Negative Review Count Tendencies for Top 5 Genres')
plt.xlabel('Genre')
plt.ylabel('Review Count')
# Out:
# Text(0, 0.5, 'Review Count')

# %% [markdown]
# It is difficult to interpret the data for genres other than action, so we illustrate the other four genres seperately.

# %%
# Action is disproportionately high, so another plot excluding it 

top5minusaction_df = pd.concat([casual_df, indie_df, adventure_df, simulation_df])
melt_top5minusaction_df = pd.melt(top5minusaction_df, id_vars=['name','genre'], value_vars=['Positive','Negative'], var_name='review')

# create a barplot of the melted dataframe, use review to group positive and negative reviews together
sns.barplot(x = 'genre', y = 'value',hue = 'review',data = melt_top5minusaction_df, palette='dark')

#setting plot labels
plt.title('Observing Positive/Negative Review Count Tendencies for Top 5 Genres Excluding Action')
plt.xlabel('Genre')
plt.ylabel('Review Count')
# Out:
# Text(0, 0.5, 'Review Count')

# %% [markdown]
# These barplots shows how many Positive vs Negative reviews a game labeled as a part of one specific genre out of the top 5 most frequent genres would tend to be rated. Notably, this distribution can not account for games with multiple of these genres, which would be excluded from the analyses here and may impact results.
#
# We see that there are a disporportionate amount of reviews under the Action genre while there are smaller listed numbers of reviews for the other genres as compared to the number of games. This could be explained by the fact that the other 4 genres tend to be assigned with each other, while the Action genre may not. Additionally, Games under the Action genre may include large online games with thousands of players, to obscure RPGs with under 10 players, leading to large variation.
#
# Overall, all other genres other than Action tend to have games rated more Positively than Negatively.
# This indicates that the most common game genres still tend to be rated fairly positively, as opposed to being disliked for unoriginality. A higher amount of reviews does not necessarily mean only higher positive reviews, as genres with higher Positive review counts on average also had higher Negative review counts on average.
#
# However, Action alone has a huge overlapping deviation between Positive and Negative reviews despite having more Positive reviews on average.
# In this case, the games that fall under the genre of Action may differ in review count considerably.
#
# Relating these findings to our research question, we generally found no particular association between the most common genres and Positive/Negative rating distribution. These genres tended to be rated positively overall. Despite this, Action showed overlap between Positive and Negative rating counts due to high variability in the games under the Action label. However, we can not conclude whether this is due to Action games being highly variable in rating counts overall or restrictions in how the data was presented.

# %% [markdown]
# ### Data Analysis - Machine Learning: K-Nearest Neighbors

# %%
from sklearn.compose import make_column_selector as selector
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix

# %% [markdown]
# We will now try to see if there is a pattern amongst the related variables consistent enough to generate predictions of rating. First, we will assign labels to each game based on the % of their rating for the algorithm to predict. For example, if a game had 80% positive reviews, it would get a string label of '76-100% positive rating'. We will implement the K-Nearest Neighbors algorithm as we do not appear to have a high-dimensional problem with the number of examined features being small compared to our sample.

# %%
# return a string label of the game's % of positive reviews, based on the number of entered positive and negative reviews, or no reviews if no reviews
def get_percent(pos,neg):
 # (below gives rounded percent to 2 decimal places)
    percent_pos = 0
    final_percent = 'thisshouldntshowup'
    
    if (pos + neg) > 0:
        percent_pos = round((pos / (pos + neg)), 2)
    else:
        final_percent = 'no reviews'
        return final_percent
    
    if (0 <= percent_pos <= 0.25):
        final_percent = '0-25% positive rating'
    elif (0.26 <= percent_pos <= 0.5):
        final_percent = '26-50% positive rating'
    elif (0.51 <= percent_pos <= 0.75):
        final_percent = '51-75% positive rating'
    elif (0.76 <= percent_pos <= 1):
        final_percent = '76-100% positive rating'
        
    return final_percent 

# form a new column on the steam games dataset with the string % of positive reviews
steam_games['Percent Positive Reviews'] = steam_games.apply(lambda x: get_percent(x.Positive, x.Negative), axis=1)

# %% [markdown]
# We then assign Predictors and the predicted Dependent Variable. We exclude irrelevant variables from Predictors such as name and AppID since they would create noise. We also must exclude median playtimes as they would be correlated with average playtimes and introduce multicollinearity to the model.
# We then form our train test split groups, stratifying based on our dependent variable as we have a small underrepresented number of games with lower %ge positive ratings, reflected by our EDA above.

# %%
# excluding games that got no reviews, attempting to predict rating as a %ge range from other numerical and cat data
# picking only playtime average for 2 weeks and forever as both average and mean would be correlated
keep_columns = ['Price', 'Estimated owners', 'Peak CCU', 'Average playtime forever', 'Average playtime two weeks', 'Positive', 'Negative']
X = steam_games[keep_columns][steam_games['Percent Positive Reviews'] != 'no reviews']
y = steam_games[steam_games['Percent Positive Reviews'] != 'no reviews']['Percent Positive Reviews']

# stratify needed because of imbalanced dataset, very few low ratings 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %% [markdown]
# A Pipeline simplifies the process of preparing our predictors for analysis; the one-hot encoder converts categorical data into numerical features that can be processed by the algorithm, while the standard scaler ensures that numerical variables with more extreme variations and range (eg. games having extreme differences in average playtime as compared to price in dollars generally being around a range) do not hold more weight in the model.

# %%
num_col_selector = selector(dtype_exclude = object)
cat_col_selector = selector(dtype_include = object)

num_col = num_col_selector(X)
cat_col = cat_col_selector(X)

preprocessor = ColumnTransformer([ 
    ("one_hot_encoder", OneHotEncoder(handle_unknown='ignore'), cat_col),
    ("standard_scaler", StandardScaler(), num_col)
])

steam_games_clf = Pipeline([
    ('preprocessing', preprocessor), 
    ('classifier', KNeighborsClassifier())
])

# %% [markdown]
# We perform a grid search to refine our model and find the most optimal number of neighbors for our classification, given by the best_params attribute.

# %%
param_grid = {
    'classifier__n_neighbors': [3,5,7,10,15]

}
best_model = GridSearchCV(steam_games_clf, param_grid, verbose=1)

best_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# GridSearchCV(estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['Estimated '
#                                                                           'owners']),
#                                                                         ('standard_scaler',
#                                                                          StandardScaler(),
#                                                                          ['Price',
#                                                                           'Peak '
#                                                                           'CCU',
# ...

# %%
best_model.best_params_
# Out:
# {'classifier__n_neighbors': 5}

# %% [markdown]
# We generate an evaluation of Precision and Recall of the model's predicted test output of %positive ratings as compared to the true test set. Precision and Recall are highest for games with a 76-100% positive rating. This means that for games actually with a 76-100% rating, the algorithm tended to correctly identify it as such (Recall), and games of lower positive ratings were not often misidentified as having 76-100% positive ratings (Precision). We can see that both precision and recall tend to be lower for games with 50% or below positive ratings, and this is likely due to the few numbers of games we have in the dataset with a percentage of ratings this low. The suspiciously higher precision for 0-25% positive ratings may be a result of having a smaller biased sample of low rated games, giving misleading associations between the few games included in the dataset that the algorithm picked up on.

# %%
steam_games_predicted_test_Y = best_model.predict(X_test)

class_report_test = classification_report(y_test, steam_games_predicted_test_Y)
print(class_report_test)
# Out:
#                          precision    recall  f1-score   support
#
#   0-25% positive rating       0.77      0.64      0.70       550
#  26-50% positive rating       0.66      0.60      0.63      1251
#  51-75% positive rating       0.73      0.74      0.73      3056
# 76-100% positive rating       0.90      0.92      0.91      6573
#
#                accuracy                           0.82     11430
#               macro avg       0.76      0.72      0.74     11430
#            weighted avg       0.82      0.82      0.82     11430

# %% [markdown]
# ### Data Analysis - Predictive Linear Model

# %% [markdown]
# The only strongly correlated variable to Positive and Negative reviews as we assessed through the earlier correlation matrix seems to be Peak CCU, so we can also attempt to see if a predictive linear model built around CCU will perform based on Positive review count versus Positive review percentage.

# %%
# import necessary packages
import statsmodels
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %%
# generating a linear model off of data predicting positive review count based on Peak CCU
positive_count_model = smf.ols('Positive ~ Q("Peak CCU")', data = steam_games)
positive_count_model_summary = smf.ols('Positive ~ Q("Peak CCU")', data = steam_games).fit().summary()

print(positive_count_model_summary)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Positive   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                 6.854e+05
# Date:                Tue, 17 Mar 2026   Prob (F-statistic):               0.00
# Time:                        00:54:13   Log-Likelihood:            -5.7445e+05
# No. Observations:               54250   AIC:                         1.149e+06
# Df Residuals:                   54248   BIC:                         1.149e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       427.6357     41.239     10.370      0.000     346.808     508.464
# ...

# %%
# generating a linear model off of data predicting the percentage of positive reviews based off Peak CCU
# which we added as a column during the Price Boxplot visualization
positive_percent_model = smf.ols('Q("Percentage of Positive") ~ Q("Peak CCU")', data = steam_games)
positive_percent_model_summary = smf.ols('Q("Percentage of Positive") ~ Q("Peak CCU")', data = steam_games).fit().summary()

print(positive_percent_model_summary)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:     Q("Percentage of Positive")   R-squared:                       0.000
# Model:                                     OLS   Adj. R-squared:                  0.000
# Method:                          Least Squares   F-statistic:                     1.571
# Date:                         Tue, 17 Mar 2026   Prob (F-statistic):              0.210
# Time:                                 00:54:36   Log-Likelihood:            -2.6945e+05
# No. Observations:                        54250   AIC:                         5.389e+05
# Df Residuals:                            54248   BIC:                         5.389e+05
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# Predicting the count of Positive ratings from Peak CCU seems to give a suspiciously high R-squared, where variance in the peak amount of active users seems to explain variance in the number of Positive ratings. However, we next examine if Peak CCU can predict the actual percentage rating of positive reviews. When we try to apply the linear model to predicting percentage reviews, the model completely fails.
#
# Evidently, the percentage of positive reviews cannot reliably be associated with the raw count of positive reviews. This analysis shows how high linear correlations alone may be deceptive in the case of ratings, and percentages of positive ratings require additional complex consideration, as we demonstrated with our KNN algorithm above.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Our project will be focusing on data on video games, not human subjects. This data is publicly available and displayed by developers and publishers on Steam for the purpose of informing interested individuals about their games.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > We will check for and acknowledge any unusual patterns in the data for any specific games seemingly being over or under represented.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > Variables of interest we will collect information on are information such as genre and rating and other descriptive measurements of games, which pertain to the games themselves and not any individuals.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > The variables we are collecting information on with regards to video games are not based on protect human group status.
#
#
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > The data we are working with is publicly available and accessible to any interested user through Kaggle. However, the data in its edited form for the project will only be directly available through our group's local machines.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > No personal or sensitive information of individuals is being collected or analyzed. However, we will be open to information takedown requests through our contacts such as by email.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > We will likely retain the data until the members of this group graduate or longer, but we will be open to information takedown if needed. However, the datasets we will use are all still publicly available.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > We will be open to discussing and critiquing our analysis and findings with any interested stakeholders. We have looked through previous projects and work done in the area of Steam game data analysis to consider our research question.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We acknowledge that reviews collected from Steam will likely not generalize to a broader population, so we are designating our population of interest as Steam users specifically. We will examine our data and the source of our dataset to consider any biased processes that could have impacted data collection.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will design our visualizations, summary statistics, and reports to be as legible and reflective of the underlying data as possible. We will not tamper with our analyses to present our ideal findings over the facts.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > No data with PII will be used in the analyses.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > We will document each step of our analysis clearly for any future reader.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > The variables involved in the model are objective metrics of video games such as genre and achievement number that are not collected through discriminatory methods.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > We will test our model's results for fairness across the various aspects of video games.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We are looking into the most relevant variables out of the datasets available to us that can effectively describe video games and can potentially affect how people rate games. So far, game genre, playtime, game price, game achievement numbers seem like a solid start.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > We will explain as best we can why our models will behave in specific ways given the data available to it and the model's behavior.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will acknowledge the limitations we have with regards to how our models will act on limited data collected on Steam games as clearly as we can.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > We can examine how generally applicable our model of predicting Steam game ratings is on data of new games released this year to see the consistency of its performance.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > If anyone is harmed by our model, we will consider what aspect of the model could have been used to harm them and how we can clarify the intended use for our model instead. For example, if consumers were to actually base their purchasing decisions off of the model predicting game ratings and thereby denying new games a playerbase, we would clarify that the model results are intended to be predictive and reflect data collected on previously released games and cannot always generalize well.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# > We will be open to taking down our model from public access if it is misused.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > Unintended uses and/or abuses could be game publishers' playerbases being significantly impacted due to unfavorable predicted game ratings from the model, or model results of predicted ratings being used to undeservedly slander or praise particular games. We will be open to being contacted for any concerns over how our model is being used.

# %% [markdown]
# ## Discussion and Conclusion
#
# Overall, we did not find conclusive support for our initial hypothesis that game variables such as price and genre would be strongly associated with and could be used to predict the rating of games on Steam.
#
# - Using a correlation matrix to assess for game qualities having potential individual correlations with positive reviews, none of the properties of the games like price, genre, etc. showed particularly strong correlations with positive or negative review count. Meaning, the other analyses we performed to examine associations with positive reviews would not be particularly strong, even if we do find relationships.
# - We divided games into bins based on price and assessed their distributions through a box plot, and only found a weak association that games above 80 dollars tended to be rated lower on average, but not by a significant amount. The distribution had a lower mean percentage of positive reviews and maximum percentage of positive reviews, but still overlapped with other price distributions.
# - By one hot encoding each individual unique genre and visualizing the average positive review proportion per individual unique genre, we noted that certain genres associated with lower quality and player exploitation such as free-to-play and MMO games received a lower percentage of positive reviews on average, while genres associated with quality such as Indie had higher proportions of positive reviews on average.
# - We used grouped bar plots for peak CCU (the highest amounts of active players the game had) and Positive/Negative review count distributions across all games. Games were again grouped by bins of peak CCU ranges and reflected that games with higher peak player counts would tend to get higher numbers of both positive and negative reviews. Meanwhile, we melted Positive and Negative reviews per the top 5 most commonly occurring genres to observe review count patterns, showing that games tended to be rated positively overall.
# - We then used the K-nearest neighbors machine learning algorithm to see how well our data could be used to predict rating, and found that the algorithm performed the best by assessing for 5 nearest neighbors (which may lead to overfit concerns) and that it performed best in terms of both precision and recall for games with higher percentages of positive ratings, and worst in terms of recall for more negatively rated games. This makes sense as games with lower percentages of positive ratings were underrepresented in data.
# - We also assessed if a linear model would be able to predict Positive ratings as the initial correlation matrix gave a strong indication that Peak CCU may be able to predict Positive Ratings. While it was able to predict Positive Rating Counts, indicating the more players who actively were interested in a game the higher amount of Positive Ratings tended to be submitted, Positive Rating Counts themselves cannot indicate positive rating percentages.
#
# Like the findings of previous projects we were inspired off of, impacts on subjective rating is a difficult quality to assess through objective variables. Our project demonstrates that even if individual variables such as genre and price can show general associations with higher or lower game ratings, they do not always demonstrate a strong and direct influence.
#
# Limitations we encountered that would need addressing are the set up of the actual Steam game rating system as well as the representation of games in our datasets. Unlike rating systems that operate on an average scale rating, Steam game ratings simply show the percentage of people who left a positive as opposed to a negative review, failing to capture more nuanced levels of individual opinion, and the actual number of reviews can be obscured as well if they share the same percentage. Additionally, our datasets did not have as many examples of games with lower percentages of positive ratings, making it more difficult for algorithms to find clear distinctions between games with lower and higher percentages of positive ratings.
# Future work could attempt to account for the rating system by assessing differences in rating patterns accounting for the actual number count of reviews versus percentages, as well as purposefully oversample games with lower percentages of positive ratings when attempting to build predictive algorithms for rating.
